# %% [markdown]
# ## import packages and read data

# %%
import pandas as pd
import numpy as np
import os
import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## read data and EDA

# %%
path = os.path.join(os.getcwd(), 'delivery_orders_march.csv')
df = pd.read_csv(path)
df.head()
# Out:
#       orderid        pick  1st_deliver_attempt  2nd_deliver_attempt  \
# 0  2215676524  1583138397         1.583385e+09                  NaN
# 1  2219624609  1583309968         1.583463e+09         1.583799e+09
# 2  2220979489  1583306434         1.583460e+09                  NaN
# 3  2221066352  1583419016         1.583556e+09                  NaN
# 4  2222478803  1583318305         1.583480e+09                  NaN
#
#                                         buyeraddress  \
# 0  Baging ldl BUENAVISTA,PATAG.CAGAYAN Buagsong,c...
# 1  coloma's quzom CASANAS Site1 Masiyan 533A Stol...
# 2  21-O LumangDaan,Capitangan,Abucay,Bataan .Bign...
# 3  616Espiritu MARTINVILLE,MANUYO #5paraiso kengi...
# 4  L042 Summerbreezee1 L2(Balanay analyn Lot760 C...
#
#                                        selleraddress
# 0  Pantranco vill. 417 Warehouse# katipunan 532 (...
# 1  BLDG 210A Moras C42B 2B16,168 church) Complex ...
# 2  #66 150-C, DRIVE, Milagros Joe socorro Metro M...
# 3  999maII 201,26 Villaruel Barretto gen.t number...
# 4  G66MANILA Hiyas Fitness MAYSILO magdiwang Lt.4...

# %% [markdown]
# ## retrieve the state from the address

# %%
df['buyeraddress_state'] = df['buyeraddress'].apply(lambda x: x.rsplit(maxsplit=1)[-1].lower())
df['selleraddress_state'] = df['selleraddress'].apply(lambda x: x.rsplit(maxsplit=1)[-1].lower())
df
# df['buyeraddress_state'].isnull().values.any()
# df['selleraddress_state'].isnull().values.any()
# abc.isnull().sum()
# Out:
#                 orderid        pick  1st_deliver_attempt  2nd_deliver_attempt  \
# 0            2215676524  1583138397         1.583385e+09                  NaN
# 1            2219624609  1583309968         1.583463e+09         1.583799e+09
# 2            2220979489  1583306434         1.583460e+09                  NaN
# 3            2221066352  1583419016         1.583556e+09                  NaN
# 4            2222478803  1583318305         1.583480e+09                  NaN
# ...                 ...         ...                  ...                  ...
# 3176308  31504087640510  1585821728         1.585978e+09                  NaN
# 3176309  31504147352227  1585895011         1.586179e+09         1.586232e+09
# 3176310  31504462290482  1585826951         1.585965e+09                  NaN
# 3176311  31504851495943  1585891194         1.586230e+09                  NaN
# 3176312  31505199116340  1585823923         1.586153e+09         1.586231e+09
#
#                                               buyeraddress  \
# 0        Baging ldl BUENAVISTA,PATAG.CAGAYAN Buagsong,c...
# 1        coloma's quzom CASANAS Site1 Masiyan 533A Stol...
# 2        21-O LumangDaan,Capitangan,Abucay,Bataan .Bign...
# 3        616Espiritu MARTINVILLE,MANUYO #5paraiso kengi...
# 4        L042 Summerbreezee1 L2(Balanay analyn Lot760 C...
# ...                                                    ...
# 3176308  mayapis. edeliza JC274 5542 brgy.Dita, Metro M...
# 3176309  Superdome PORKY K307 Libertad, PCGCC sub.bagui...
# 3176310  Galay's 1republic 333-18 Diliman 74d Malbay fe...
# 3176311  #4560, 80south biloca vi!!age KM21, MANRESA, ,...
# 3176312  b4l13 TOLDA 792-A-5-A east...near CARRASCO Ang...
#
#                                              selleraddress buyeraddress_state  \
# 0        Pantranco vill. 417 Warehouse# katipunan 532 (...             manila
# 1        BLDG 210A Moras C42B 2B16,168 church) Complex ...             manila
# 2        #66 150-C, DRIVE, Milagros Joe socorro Metro M...             manila
# 3        999maII 201,26 Villaruel Barretto gen.t number...             manila
# 4        G66MANILA Hiyas Fitness MAYSILO magdiwang Lt.4...              luzon
# ...                                                    ...                ...
# 3176308  Intimate St) compound. Sekiat 2B8 98-B Mel far...             manila
# 3176309  13th 3616 Pilipinas, :1v26 1f-5 (Village) bl10...             manila
# 3176310  Lane, 379B 1739A Ivc AFPFC Cainta, Waterpark, ...             manila
# 3176311  lrt-2 Consolacion 224-A Paradise 6D 36st champ...              luzon
# 3176312  (Jeepney Kaligayan VANVAN Salud ASA Lauan A-55...              luzon
#
#         selleraddress_state
# 0                    manila
# 1                    manila
# 2                    manila
# 3                    manila
# 4                    manila
# ...                     ...
# 3176308              manila
# 3176309              manila
# 3176310              manila
# 3176311              manila
# 3176312              manila
#
# [3176313 rows x 8 columns]

# %% [markdown]
# ## delivery standards: SLA(Service Level Agreements ) matrix

# %% [markdown]
# 1. Working Days are defined as "Mon - Sat", excluding Public Holidays.
# 2. SLA calculation begins from the next day after pickup (Day 0 = Day of Pickup; Day 1 = Next Day after Pickup)
# 3. 2nd Attempt must be no later than 3 working days after the 1st Attempt, regardless of origin to destination route (Day 0 = Day of 1st Attempt; Day 1 = Next Day after 1st Attempt).

# %%
origin_seller=['Metro Manila','Luzon','Visayas','Mindanao']
destination_buyer=['Metro Manila','Luzon','Visayas','Mindanao']
working_days = [[3,5,7,7],[5,5,7,7],[7,7,7,7],[7,7,7,7]]
sla_matrix = pd.DataFrame(working_days,index=origin_seller,columns=destination_buyer)
sla_matrix.style.set_caption("1st Attempt SLA (Working Days)")
# Out:
# <style  type="text/css" >
# </style><table id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1" ><caption>1st Attempt SLA (Working Days)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Metro Manila</th>        <th class="col_heading level0 col1" >Luzon</th>        <th class="col_heading level0 col2" >Visayas</th>        <th class="col_heading level0 col3" >Mindanao</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1level0_row0" class="row_heading level0 row0" >Metro Manila</th>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row0_col1" class="data row0 col1" >5</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row0_col2" class="data row0 col2" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row0_col3" class="data row0 col3" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1level0_row1" class="row_heading level0 row1" >Luzon</th>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row1_col0" class="data row1 col0" >5</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row1_col2" class="data row1 col2" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row1_col3" class="data row1 col3" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1level0_row2" class="row_heading level0 row2" >Visayas</th>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row2_col1" class="data row2 col1" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row2_col2" class="data row2 col2" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row2_col3" class="data row2 col3" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1level0_row3" class="row_heading level0 row3" >Mindanao</th>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row3_col0" class="data row3 col0" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row3_col1" class="data row3 col1" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row3_col2" class="data row3 col2" >7</td>
#                         <td id="T_fbcf635c_ef24_11eb_bd96_c4b301d157a1row3_col3" class="data row3 col3" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## map standard delivery days to each order

# %%
res = []

for row in df.itertuples(index=False):
    
    ori = row.selleraddress_state
    des = row.buyeraddress_state
    
    if ori == 'manila' and des == 'manila':
        res.append(3)
    elif (ori == 'manila' and des == 'luzon') or (ori == 'luzon' and des == 'manila') or (ori == 'luzon' and des == 'luzon'):
        res.append(5)
    else:
        res.append(7)

df['delivery_days'] = res

# %% [markdown]
# ## classify whether the orders were reshipped

# %%
# orders that were not reshipped： 2nd_deliver_attempt == NaN
nan = df[df['2nd_deliver_attempt'].isna()].reset_index(drop = True)

# %%
# orders that were reshipped： 2nd_deliver_attempt != NaN
notna = df[df['2nd_deliver_attempt'].notna()].reset_index(drop = True)

# %% [markdown]
# ## convert timestamps to dates and store into new columns

# %%
# epoch time to GMT+8
nan['pick_date'] = pd.to_datetime(nan['pick'], unit='s') + datetime.timedelta(hours = 8)
nan['pick_date'] = nan['pick_date'].dt.date

nan['1st_date'] = pd.to_datetime(nan['1st_deliver_attempt'], unit='s') + datetime.timedelta(hours = 8)
nan['1st_date'] = nan['1st_date'].dt.date

nan = nan.drop(columns=['pick','1st_deliver_attempt','2nd_deliver_attempt','buyeraddress','selleraddress'])
nan
# Out:
#                 orderid buyeraddress_state selleraddress_state  delivery_days  \
# 0            2215676524             manila              manila              3
# 1            2220979489             manila              manila              3
# 2            2221066352             manila              manila              3
# 3            2222478803              luzon              manila              5
# 4            2222597288             manila              manila              3
# ...                 ...                ...                 ...            ...
# 1819306  31502339045455             manila              manila              3
# 1819307  31503788156046             manila              manila              3
# 1819308  31504087640510             manila              manila              3
# 1819309  31504462290482             manila              manila              3
# 1819310  31504851495943              luzon              manila              5
#
#           pick_date    1st_date
# 0        2020-03-02  2020-03-05
# 1        2020-03-04  2020-03-06
# 2        2020-03-05  2020-03-07
# 3        2020-03-04  2020-03-06
# 4        2020-03-04  2020-03-07
# ...             ...         ...
# 1819306  2020-04-03  2020-04-07
# 1819307  2020-04-03  2020-04-04
# 1819308  2020-04-02  2020-04-04
# 1819309  2020-04-02  2020-04-04
# 1819310  2020-04-03  2020-04-07
#
# [1819311 rows x 6 columns]

# %%
notna['pick_date'] = pd.to_datetime(notna['pick'], unit='s') + datetime.timedelta(hours = 8)
notna['pick_date'] = notna['pick_date'].dt.date

notna['1st_date'] = pd.to_datetime(notna['1st_deliver_attempt'], unit='s') + datetime.timedelta(hours = 8)
notna['1st_date'] = notna['1st_date'].dt.date

notna['2nd_date'] = pd.to_datetime(notna['2nd_deliver_attempt'], unit='s') + datetime.timedelta(hours = 8)
notna['2nd_date'] = notna['2nd_date'].dt.date

notna = notna.drop(columns=['pick','1st_deliver_attempt','2nd_deliver_attempt','buyeraddress','selleraddress'])
notna
# Out:
#                 orderid buyeraddress_state selleraddress_state  delivery_days  \
# 0            2219624609             manila              manila              3
# 1            2222738456             manila              manila              3
# 2            2224704587              luzon              manila              5
# 3            2227771109             manila              manila              3
# 4            2227783105             manila              manila              3
# ...                 ...                ...                 ...            ...
# 1356997  31497388770741             manila              manila              3
# 1356998  31500223560475             manila              manila              3
# 1356999  31502490611412              luzon              manila              5
# 1357000  31504147352227             manila              manila              3
# 1357001  31505199116340              luzon              manila              5
#
#           pick_date    1st_date    2nd_date
# 0        2020-03-04  2020-03-06  2020-03-10
# 1        2020-03-02  2020-03-05  2020-03-09
# 2        2020-03-04  2020-03-05  2020-03-09
# 3        2020-03-02  2020-03-04  2020-03-05
# 4        2020-03-02  2020-03-05  2020-03-07
# ...             ...         ...         ...
# 1356997  2020-04-03  2020-04-06  2020-04-07
# 1356998  2020-04-03  2020-04-06  2020-04-07
# 1356999  2020-04-02  2020-04-04  2020-04-06
# 1357000  2020-04-03  2020-04-06  2020-04-07
# 1357001  2020-04-02  2020-04-06  2020-04-07
#
# [1357002 rows x 7 columns]

# %% [markdown]
# ## convert date to integer

# %%
nan['pick_transform'] = (nan['pick_date']- datetime.date(2020,3,1)).dt.days + 1
nan['1st_transform']  = (nan['1st_date']- datetime.date(2020,3,1)).dt.days + 1

notna['pick_transform'] = (notna['pick_date']- datetime.date(2020,3,1)).dt.days + 1
notna['1st_transform']  = (notna['1st_date']- datetime.date(2020,3,1)).dt.days + 1
notna['2nd_transform']  = (notna['2nd_date']- datetime.date(2020,3,1)).dt.days + 1

# %% [markdown]
# ## check if shipment is delayed

# %%
not_working_days = [1,8,15,22,25,29,30,31,36]

# %%
nan['working_days'] = nan['1st_transform'] - nan['pick_transform']

for ii in not_working_days:
    nan.loc[(nan['pick_transform'] < ii) & (nan['1st_transform'] > ii), 'working_days'] -= 1

# %%
nan['is_late'] = np.where(nan['working_days'] > nan['delivery_days'],1,0)
nan
# Out:
#                 orderid buyeraddress_state selleraddress_state  delivery_days  \
# 0            2215676524             manila              manila              3
# 1            2220979489             manila              manila              3
# 2            2221066352             manila              manila              3
# 3            2222478803              luzon              manila              5
# 4            2222597288             manila              manila              3
# ...                 ...                ...                 ...            ...
# 1819306  31502339045455             manila              manila              3
# 1819307  31503788156046             manila              manila              3
# 1819308  31504087640510             manila              manila              3
# 1819309  31504462290482             manila              manila              3
# 1819310  31504851495943              luzon              manila              5
#
#           pick_date    1st_date  pick_transform  1st_transform  working_days  \
# 0        2020-03-02  2020-03-05               2              5             3
# 1        2020-03-04  2020-03-06               4              6             2
# 2        2020-03-05  2020-03-07               5              7             2
# 3        2020-03-04  2020-03-06               4              6             2
# 4        2020-03-04  2020-03-07               4              7             3
# ...             ...         ...             ...            ...           ...
# 1819306  2020-04-03  2020-04-07              34             38             3
# 1819307  2020-04-03  2020-04-04              34             35             1
# 1819308  2020-04-02  2020-04-04              33             35             2
# 1819309  2020-04-02  2020-04-04              33             35             2
# 1819310  2020-04-03  2020-04-07              34             38             3
#
#          is_late
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1819306        0
# 1819307        0
# 1819308        0
# 1819309        0
# 1819310        0
#
# [1819311 rows x 10 columns]

# %%
notna['working_days_1'] = notna['1st_transform'] - notna['pick_transform']
notna['working_days_2'] = notna['2nd_transform'] - notna['1st_transform']

for ii in not_working_days:
    notna.loc[(notna['pick_transform'] < ii) & (notna['1st_transform'] > ii), 'working_days_1'] -= 1
    notna.loc[(notna['1st_transform'] < ii) & (notna['2nd_transform'] > ii), 'working_days_2'] -= 1

# %%
notna['is_late'] = np.where(notna['working_days_1'] > notna['delivery_days'],1,0)
is_late_2 = np.where(notna['working_days_2'] > 3,1,0)
notna['is_late'].loc[is_late_2 == 1] = 1
notna
# Out:
#                 orderid buyeraddress_state selleraddress_state  delivery_days  \
# 0            2219624609             manila              manila              3
# 1            2222738456             manila              manila              3
# 2            2224704587              luzon              manila              5
# 3            2227771109             manila              manila              3
# 4            2227783105             manila              manila              3
# ...                 ...                ...                 ...            ...
# 1356997  31497388770741             manila              manila              3
# 1356998  31500223560475             manila              manila              3
# 1356999  31502490611412              luzon              manila              5
# 1357000  31504147352227             manila              manila              3
# 1357001  31505199116340              luzon              manila              5
#
#           pick_date    1st_date    2nd_date  pick_transform  1st_transform  \
# 0        2020-03-04  2020-03-06  2020-03-10               4              6
# 1        2020-03-02  2020-03-05  2020-03-09               2              5
# 2        2020-03-04  2020-03-05  2020-03-09               4              5
# 3        2020-03-02  2020-03-04  2020-03-05               2              4
# 4        2020-03-02  2020-03-05  2020-03-07               2              5
# ...             ...         ...         ...             ...            ...
# 1356997  2020-04-03  2020-04-06  2020-04-07              34             37
# 1356998  2020-04-03  2020-04-06  2020-04-07              34             37
# 1356999  2020-04-02  2020-04-04  2020-04-06              33             35
# 1357000  2020-04-03  2020-04-06  2020-04-07              34             37
# 1357001  2020-04-02  2020-04-06  2020-04-07              33             37
#
#          2nd_transform  working_days_1  working_days_2  is_late
# 0                   10               2               3        0
# 1                    9               3               3        0
# 2                    9               1               3        0
# 3                    5               2               1        0
# 4                    7               3               2        0
# ...                ...             ...             ...      ...
# 1356997             38               2               1        0
# 1356998             38               2               1        0
# 1356999             37               2               1        0
# 1357000             38               2               1        0
# 1357001             38               3               1        0
#
# [1357002 rows x 13 columns]

# %% [markdown]
# ## output

# %%
col = ['orderid', 'is_late']
result = pd.concat([nan[col], notna[col]], ignore_index=True)
result
# Out:
#                 orderid  is_late
# 0            2215676524        0
# 1            2220979489        0
# 2            2221066352        0
# 3            2222478803        0
# 4            2222597288        0
# ...                 ...      ...
# 3176308  31497388770741        0
# 3176309  31500223560475        0
# 3176310  31502490611412        0
# 3176311  31504147352227        0
# 3176312  31505199116340        0
#
# [3176313 rows x 2 columns]

# %%
result.to_csv('submission_20200711_data_analytics.csv',index=False)
